# %% [markdown]
# ## Visualize training

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import griddata
import numpy as np

data = []
dice_list = []

for weight_ground_truth in [0.6,0.7]:
    for alpha in [0.5]:
        for alpha_union in [0.4,0.6,0.8]:
            path = f"/home/albert/ml/Contrails/notebooks/full_dataset/test_use_all_bands/resnest26d_ash_attention_sample_loss/resnest101e_alpha={alpha}_alpha_union={alpha_union}_weight_ground_truth={weight_ground_truth}/version_0/metrics.csv"
            label = f"alpha={alpha}_alpha_union={alpha_union}_weight_ground_truth={weight_ground_truth}"
            metrics = pd.read_csv(path)
            metrics = metrics.dropna(subset = ['val_dice']).set_index("epoch")
            maximum = metrics.dropna(subset = ['val_dice']).max()["val_dice"]#[["val_dice","epoch"]]
            data.append([weight_ground_truth, alpha_union, maximum])
            dice_list.append(f" max: {maximum:.3f} "+label)

for weight_ground_truth in [0.55,0.45]:
    for alpha in [0.5]:
        for alpha_union in [0.75,0.85]:
            path = f"/home/albert/ml/Contrails/notebooks/full_dataset/test_use_all_bands/resnest26d_ash_attention_sample_loss/resnest101e_alpha={alpha}_alpha_union={alpha_union}_weight_ground_truth={weight_ground_truth}/version_0/metrics.csv"
            label = f"alpha={alpha}_alpha_union={alpha_union}_weight_ground_truth={weight_ground_truth}"
            metrics = pd.read_csv(path)
            metrics = metrics.dropna(subset = ['val_dice']).set_index("epoch")
            maximum = metrics.dropna(subset = ['val_dice']).max()["val_dice"]#[["val_dice","epoch"]]
            data.append([weight_ground_truth, alpha_union, maximum])
            dice_list.append(f" max: {maximum:.3f} "+label)            

dice_list.sort
for element in dice_list: print(element)



import matplotlib.pyplot as plt

x = [i[0] for i in data]
y = [i[1] for i in data]
z = [i[2] for i in data]

# plt.figure(figsize=(15,15))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create a mesh grid
X,Y = np.meshgrid(x,y)

# Interpolate the data
from scipy.interpolate import griddata
Z = griddata((x,y), z, (X,Y), method='cubic')

# Plot the points with a color gradient
ax.scatter(x,y,z,c=z,cmap='coolwarm', alpha=1)

# Add a color bar which maps values to colors
# fig.colorbar(surf)

# Plot lines from points to surface
for i in range(len(x)):
    ax.plot([x[i], x[i]], [y[i], y[i]], [0.613, z[i]], color='black', alpha=0.5)

# Plot the surface
ax.set_xlabel('weight_ground_truth')
ax.set_ylabel('alpha_union')
ax.set_zlabel('maximum')

plt.show()
# Out:
#  max: 0.616 alpha=0.5_alpha_union=0.4_weight_ground_truth=0.6
#  max: 0.623 alpha=0.5_alpha_union=0.6_weight_ground_truth=0.6
#  max: 0.625 alpha=0.5_alpha_union=0.8_weight_ground_truth=0.6
#  max: 0.615 alpha=0.5_alpha_union=0.4_weight_ground_truth=0.7
#  max: 0.619 alpha=0.5_alpha_union=0.6_weight_ground_truth=0.7
#  max: 0.616 alpha=0.5_alpha_union=0.8_weight_ground_truth=0.7
#  max: 0.622 alpha=0.5_alpha_union=0.75_weight_ground_truth=0.55
#  max: 0.624 alpha=0.5_alpha_union=0.85_weight_ground_truth=0.55
#  max: 0.611 alpha=0.5_alpha_union=0.75_weight_ground_truth=0.45
#  max: 0.626 alpha=0.5_alpha_union=0.85_weight_ground_truth=0.45

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import griddata
import numpy as np

data = []
dice_list = []

for weight_ground_truth in [0.6]:
    for alpha in [0.35,0.5,0.65]:
        for alpha_union in [0.4,0.6,0.8]:
            path = f"/home/albert/ml/Contrails/notebooks/full_dataset/test_use_all_bands/resnest26d_ash_attention_sample_loss/resnest101e_alpha={alpha}_alpha_union={alpha_union}_weight_ground_truth={weight_ground_truth}/version_0/metrics.csv"
            label = f"alpha={alpha}_alpha_union={alpha_union}_weight_ground_truth={weight_ground_truth}"
            metrics = pd.read_csv(path)
            metrics = metrics.dropna(subset = ['val_dice']).set_index("epoch")
            maximum = metrics.dropna(subset = ['val_dice']).max()["val_dice"]#[["val_dice","epoch"]]
            maximum = metrics.dropna(subset = ['val_dice']).max()["val_dice"]#[["val_dice","epoch"]]
            data.append([alpha, alpha_union, maximum])
            dice_list.append(f" max: {maximum:.3f} "+label)

dice_list.sort
for element in dice_list: print(element)



import matplotlib.pyplot as plt

x = [i[0] for i in data]
y = [i[1] for i in data]
z = [i[2] for i in data]

# plt.figure(figsize=(15,15))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create a mesh grid
X,Y = np.meshgrid(x,y)

# Interpolate the data
from scipy.interpolate import griddata
Z = griddata((x,y), z, (X,Y), method='cubic')

# Plot the points with a color gradient
ax.scatter(x,y,z,c=z,cmap='coolwarm', alpha=1)

# Add a color bar which maps values to colors
# fig.colorbar(surf)

# Plot lines from points to surface
for i in range(len(x)):
    ax.plot([x[i], x[i]], [y[i], y[i]], [0.62, z[i]], color='black', alpha=0.5)

# Plot the surface
ax.set_xlabel('alpha')
ax.set_ylabel('alpha_union')
ax.set_zlabel('maximum')

plt.show()
# Out:
#  max: 0.607 alpha=0.35_alpha_union=0.4_weight_ground_truth=0.6
#  max: 0.612 alpha=0.35_alpha_union=0.6_weight_ground_truth=0.6
#  max: 0.614 alpha=0.35_alpha_union=0.8_weight_ground_truth=0.6
#  max: 0.616 alpha=0.5_alpha_union=0.4_weight_ground_truth=0.6
#  max: 0.623 alpha=0.5_alpha_union=0.6_weight_ground_truth=0.6
#  max: 0.625 alpha=0.5_alpha_union=0.8_weight_ground_truth=0.6
#  max: 0.615 alpha=0.65_alpha_union=0.4_weight_ground_truth=0.6
#  max: 0.619 alpha=0.65_alpha_union=0.6_weight_ground_truth=0.6
#  max: 0.616 alpha=0.65_alpha_union=0.8_weight_ground_truth=0.6

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(15,20))
for weight_ground_truth in [0.45]:
    for alpha in [0.45,0.5]:
        for alpha_union in [0.75,0.85]:
            path = f"/home/albert/ml/Contrails/notebooks/full_dataset/test_use_all_bands/resnest26d_ash_attention_sample_loss/resnest101e_alpha={alpha}_alpha_union={alpha_union}_weight_ground_truth={weight_ground_truth}/version_0/metrics.csv"
            label = f"alpha={alpha}_alpha_union={alpha_union}_weight_ground_truth={weight_ground_truth}"
            metrics = pd.read_csv(path)
            metrics = metrics.dropna(subset = ['val_dice']).set_index("epoch")
            linestyle = {0.75:"dotted",0.85:"-"}[alpha_union]
            color = {0.45:(0.6,0,0),0.5:(0,0,0.5)}[alpha]
            plt.plot(metrics['val_dice'], label=label, linestyle = linestyle, color = color)
            maximum = metrics.dropna(subset = ['val_dice']).max()["val_dice"]#[["val_dice","epoch"]]
            print(label + " max: {:.3f}".format(maximum))
plt.legend()
plt.show()
# Out:
# alpha=0.45_alpha_union=0.75_weight_ground_truth=0.45 max: 0.613
# alpha=0.45_alpha_union=0.85_weight_ground_truth=0.45 max: 0.622
# alpha=0.5_alpha_union=0.75_weight_ground_truth=0.45 max: 0.611
# alpha=0.5_alpha_union=0.85_weight_ground_truth=0.45 max: 0.626

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(15,20))
for weight_ground_truth in [0.55]:
    for alpha in [0.45,0.5]:
        for alpha_union in [0.75,0.85]:
            path = f"/home/albert/ml/Contrails/notebooks/full_dataset/test_use_all_bands/resnest26d_ash_attention_sample_loss/resnest101e_alpha={alpha}_alpha_union={alpha_union}_weight_ground_truth={weight_ground_truth}/version_0/metrics.csv"
            label = f"alpha={alpha}_alpha_union={alpha_union}_weight_ground_truth={weight_ground_truth}"
            metrics = pd.read_csv(path)
            metrics = metrics.dropna(subset = ['val_dice']).set_index("epoch")
            linestyle = {0.75:"dotted",0.85:"-"}[alpha_union]
            color = {0.45:(0.6,0,0),0.5:(0,0,0.5)}[alpha]
            plt.plot(metrics['val_dice'], label=label, linestyle = linestyle, color = color)
            maximum = metrics.dropna(subset = ['val_dice']).max()["val_dice"]#[["val_dice","epoch"]]
            print(label + " max: {:.3f}".format(maximum))
plt.legend()
plt.show()
# Out:
# alpha=0.45_alpha_union=0.75_weight_ground_truth=0.55 max: 0.619
# alpha=0.45_alpha_union=0.85_weight_ground_truth=0.55 max: 0.619
# alpha=0.5_alpha_union=0.75_weight_ground_truth=0.55 max: 0.622
# alpha=0.5_alpha_union=0.85_weight_ground_truth=0.55 max: 0.624

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import griddata
import numpy as np

data = []
dice_list = []
for weight_ground_truth in [0.55]: #[0.55,0.45]
    for alpha in [0.45,0.5]:
        for alpha_union in [0.75,0.85]:
            path = f"/home/albert/ml/Contrails/notebooks/full_dataset/test_use_all_bands/resnest26d_ash_attention_sample_loss/resnest101e_alpha={alpha}_alpha_union={alpha_union}_weight_ground_truth={weight_ground_truth}/version_0/metrics.csv"
            label = f"alpha={alpha}_alpha_union={alpha_union}_weight_ground_truth={weight_ground_truth}"
            metrics = pd.read_csv(path)
            metrics = metrics.dropna(subset = ['val_dice']).set_index("epoch")
            maximum = metrics.dropna(subset = ['val_dice']).max()["val_dice"]#[["val_dice","epoch"]]
            data.append([alpha, alpha_union, maximum])
            dice_list.append(f" max: {maximum:.3f} "+label)

dice_list.sort
for element in dice_list: print(element)

import matplotlib.pyplot as plt

x = [i[0] for i in data]
y = [i[1] for i in data]
z = [i[2] for i in data]

# plt.figure(figsize=(15,15))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create a mesh grid
X,Y = np.meshgrid(x,y)

# Interpolate the data
from scipy.interpolate import griddata
Z = griddata((x,y), z, (X,Y), method='cubic')

# Plot the points with a color gradient
ax.scatter(x,y,z,c=z,cmap='coolwarm', alpha=1)

# Add a color bar which maps values to colors
# fig.colorbar(surf)

# Plot lines from points to surface
for i in range(len(x)):
    ax.plot([x[i], x[i]], [y[i], y[i]], [0.62, z[i]], color='black', alpha=0.5)

# Plot the surface
ax.set_xlabel('alpha')
ax.set_ylabel('alpha_union')
ax.set_zlabel('maximum')

plt.show()
# Out:
#  max: 0.619 alpha=0.45_alpha_union=0.75_weight_ground_truth=0.55
#  max: 0.619 alpha=0.45_alpha_union=0.85_weight_ground_truth=0.55
#  max: 0.622 alpha=0.5_alpha_union=0.75_weight_ground_truth=0.55
#  max: 0.624 alpha=0.5_alpha_union=0.85_weight_ground_truth=0.55

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import griddata
import numpy as np

data = []
dice_list = []
for weight_ground_truth in [0.45]: #[0.55,0.45]
    for alpha in [0.45,0.5]:
        for alpha_union in [0.75,0.85]:
            path = f"/home/albert/ml/Contrails/notebooks/full_dataset/test_use_all_bands/resnest26d_ash_attention_sample_loss/resnest101e_alpha={alpha}_alpha_union={alpha_union}_weight_ground_truth={weight_ground_truth}/version_0/metrics.csv"
            label = f"alpha={alpha}_alpha_union={alpha_union}_weight_ground_truth={weight_ground_truth}"
            metrics = pd.read_csv(path)
            metrics = metrics.dropna(subset = ['val_dice']).set_index("epoch")
            maximum = metrics.dropna(subset = ['val_dice']).max()["val_dice"]#[["val_dice","epoch"]]
            data.append([alpha, alpha_union, maximum])
            dice_list.append(f" max: {maximum:.3f} "+label)

dice_list.sort
for element in dice_list: print(element)

import matplotlib.pyplot as plt

x = [i[0] for i in data]
y = [i[1] for i in data]
z = [i[2] for i in data]

# plt.figure(figsize=(15,15))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create a mesh grid
X,Y = np.meshgrid(x,y)

# Interpolate the data
from scipy.interpolate import griddata
Z = griddata((x,y), z, (X,Y), method='cubic')

# Plot the points with a color gradient
ax.scatter(x,y,z,c=z,cmap='coolwarm', alpha=1)

# Add a color bar which maps values to colors
# fig.colorbar(surf)

# Plot lines from points to surface
for i in range(len(x)):
    ax.plot([x[i], x[i]], [y[i], y[i]], [0.62, z[i]], color='black', alpha=0.5)

# Plot the surface
ax.set_xlabel('alpha')
ax.set_ylabel('alpha_union')
ax.set_zlabel('maximum')

plt.show()
# Out:
#  max: 0.613 alpha=0.45_alpha_union=0.75_weight_ground_truth=0.45
#  max: 0.622 alpha=0.45_alpha_union=0.85_weight_ground_truth=0.45
#  max: 0.611 alpha=0.5_alpha_union=0.75_weight_ground_truth=0.45
#  max: 0.626 alpha=0.5_alpha_union=0.85_weight_ground_truth=0.45

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import griddata
import numpy as np

data = []
dice_list = []
for weight_ground_truth in [0.55,0.45]:
    for alpha in [0.45,0.5]:
        for alpha_union in [0.85]:
            path = f"/home/albert/ml/Contrails/notebooks/full_dataset/test_use_all_bands/resnest26d_ash_attention_sample_loss/resnest101e_alpha={alpha}_alpha_union={alpha_union}_weight_ground_truth={weight_ground_truth}/version_0/metrics.csv"
            label = f"alpha={alpha}_alpha_union={alpha_union}_weight_ground_truth={weight_ground_truth}"
            metrics = pd.read_csv(path)
            metrics = metrics.dropna(subset = ['val_dice']).set_index("epoch")
            maximum = metrics.dropna(subset = ['val_dice']).max()["val_dice"]#[["val_dice","epoch"]]
            data.append([alpha, weight_ground_truth, maximum])
            dice_list.append(f" max: {maximum:.3f} "+label)

dice_list.sort
for element in dice_list: print(element)

import matplotlib.pyplot as plt

x = [i[0] for i in data]
y = [i[1] for i in data]
z = [i[2] for i in data]

# plt.figure(figsize=(15,15))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create a mesh grid
X,Y = np.meshgrid(x,y)

# Interpolate the data
from scipy.interpolate import griddata
Z = griddata((x,y), z, (X,Y), method='cubic')

# Plot the points with a color gradient
ax.scatter(x,y,z,c=z,cmap='coolwarm', alpha=1)

# Add a color bar which maps values to colors
# fig.colorbar(surf)

# Plot lines from points to surface
for i in range(len(x)):
    ax.plot([x[i], x[i]], [y[i], y[i]], [0.62, z[i]], color='black', alpha=0.5)

# Plot the surface
ax.set_xlabel('alpha')
ax.set_ylabel('weight_ground_truth')
ax.set_zlabel('maximum')

plt.show()
# Out:
#  max: 0.619 alpha=0.45_alpha_union=0.85_weight_ground_truth=0.55
#  max: 0.624 alpha=0.5_alpha_union=0.85_weight_ground_truth=0.55
#  max: 0.622 alpha=0.45_alpha_union=0.85_weight_ground_truth=0.45
#  max: 0.626 alpha=0.5_alpha_union=0.85_weight_ground_truth=0.45
